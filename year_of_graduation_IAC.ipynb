# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_excel("/content/Final Lead Data.xlsx")

# %%
df.head()
# Out:
#       ID First Name              Email Gender City                 Created  \
# 0  68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1  68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2  68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3  68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4  68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
#
#   Position         New College Name Colleges  Academic Year  \
# 0      NaN                      NaN      NaN            NaN
# 1      NaN  Lords Universal College      NaN            NaN
# 2      NaN                      NaN      NaN            NaN
# 3      NaN                      NaN      NaN            NaN
# 4      NaN        B.k Birla college      NaN            NaN
#
#   Branch/ Specialisation Other Branch What is your current academic year?  \
# 0                    NaN          NaN                                 NaN
# ...

# %%
df['Created']
# Out:
# 0       04/27/2022 01:41:38 pm
# 1       04/22/2022 04:08:38 pm
# 2       04/16/2022 10:31:59 pm
# 3       04/13/2022 10:05:15 pm
# 4       03/26/2022 07:02:48 pm
#                  ...
# 5298    10/16/2019 10:19:42 am
# 5299    10/16/2019 10:19:41 am
# 5300    10/16/2019 10:19:10 am
# 5301    10/16/2019 10:19:08 am
# 5302    10/16/2019 10:19:06 am
# Name: Created, Length: 5303, dtype: object

# %%
df.dtypes
# Out:
# ID                                                          int64
# First Name                                                 object
# Email                                                      object
# Gender                                                     object
# City                                                       object
# Created                                                    object
# Position                                                   object
# New College Name                                           object
# Colleges                                                   object
# Academic Year                                             float64
# Branch/ Specialisation                                     object
# Other Branch                                               object
# What is your current academic year?                        object
# Company Name/ College Name                                 object
# ...

# %%
df.isnull().sum()
# Out:
# ID                                                           0
# First Name                                                   0
# Email                                                        0
# Gender                                                    5103
# City                                                      5248
# Created                                                      0
# Position                                                  5297
# New College Name                                          3485
# Colleges                                                  3622
# Academic Year                                             2785
# Branch/ Specialisation                                    2783
# Other Branch                                              4659
# What is your current academic year?                       5172
# Company Name/ College Name                                5065
# Would you like to know more about us and our programs?       0
# ...

# %%
df.head()
# Out:
#                   Created Position         New College Name Colleges  \
# 0  04/27/2022 01:41:38 pm      NaN                      NaN      NaN
# 1  04/22/2022 04:08:38 pm      NaN  Lords Universal College      NaN
# 2  04/16/2022 10:31:59 pm      NaN                      NaN      NaN
# 3  04/13/2022 10:05:15 pm      NaN                      NaN      NaN
# 4  03/26/2022 07:02:48 pm      NaN        B.k Birla college      NaN
#
#    Academic Year Branch/ Specialisation Other Branch  \
# 0            NaN                    NaN          NaN
# 1            NaN                    NaN          NaN
# 2            NaN                    NaN          NaN
# 3            NaN                    NaN          NaN
# 4            NaN                    NaN          NaN
#
#   What is your current academic year? Company Name/ College Name  \
# 0                                 NaN                        NaN
# 1                                 NaN                        NaN
# ...

# %%
df['Created'].head()
# Out:
# 0    04/27/2022 01:41:38 pm
# 1    04/22/2022 04:08:38 pm
# 2    04/16/2022 10:31:59 pm
# 3    04/13/2022 10:05:15 pm
# 4    03/26/2022 07:02:48 pm
# Name: Created, dtype: object

# %%
df['year'] = pd.DatetimeIndex(df['Created']).year

# %%
df.head()
# Out:
#       ID First Name              Email Gender City                 Created  \
# 0  68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1  68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2  68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3  68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4  68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
#
#   Position         New College Name Colleges  Academic Year  \
# 0      NaN                      NaN      NaN            NaN
# 1      NaN  Lords Universal College      NaN            NaN
# 2      NaN                      NaN      NaN            NaN
# 3      NaN                      NaN      NaN            NaN
# 4      NaN        B.k Birla college      NaN            NaN
#
#   Branch/ Specialisation Other Branch What is your current academic year?  \
# 0                    NaN          NaN                                 NaN
# ...

# %%
pd.to_datetime(df['year'])
# Out:
# 0      1970-01-01 00:00:00.000002022
# 1      1970-01-01 00:00:00.000002022
# 2      1970-01-01 00:00:00.000002022
# 3      1970-01-01 00:00:00.000002022
# 4      1970-01-01 00:00:00.000002022
#                     ...
# 5298   1970-01-01 00:00:00.000002019
# 5299   1970-01-01 00:00:00.000002019
# 5300   1970-01-01 00:00:00.000002019
# 5301   1970-01-01 00:00:00.000002019
# 5302   1970-01-01 00:00:00.000002019
# Name: year, Length: 5303, dtype: datetime64[ns]

# %%
df.head()
# Out:
#       ID First Name              Email Gender City                 Created  \
# 0  68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1  68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2  68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3  68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4  68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
#
#   Position         New College Name Colleges  Academic Year  \
# 0      NaN                      NaN      NaN            NaN
# 1      NaN  Lords Universal College      NaN            NaN
# 2      NaN                      NaN      NaN            NaN
# 3      NaN                      NaN      NaN            NaN
# 4      NaN        B.k Birla college      NaN            NaN
#
#   Branch/ Specialisation Other Branch What is your current academic year?  \
# 0                    NaN          NaN                                 NaN
# ...

# %%
df.dtypes
# Out:
# ID                                                          int64
# First Name                                                 object
# Email                                                      object
# Gender                                                     object
# City                                                       object
# Created                                                    object
# Position                                                   object
# New College Name                                           object
# Colleges                                                   object
# Academic Year                                             float64
# Branch/ Specialisation                                     object
# Other Branch                                               object
# What is your current academic year?                        object
# Company Name/ College Name                                 object
# ...

# %%
df['Passing year'] = df['year']+4

# %%
df.head()
# Out:
#       ID First Name              Email Gender City                 Created  \
# 0  68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1  68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2  68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3  68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4  68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
#
#   Position         New College Name Colleges  Academic Year  \
# 0      NaN                      NaN      NaN            NaN
# 1      NaN  Lords Universal College      NaN            NaN
# 2      NaN                      NaN      NaN            NaN
# 3      NaN                      NaN      NaN            NaN
# 4      NaN        B.k Birla college      NaN            NaN
#
#   Branch/ Specialisation Other Branch What is your current academic year?  \
# 0                    NaN          NaN                                 NaN
# ...

# %%
df.isnull().sum()
# Out:
# ID                                                           0
# First Name                                                   0
# Email                                                        0
# Gender                                                    5103
# City                                                      5248
# Created                                                      0
# Position                                                  5297
# New College Name                                          3485
# Colleges                                                  3622
# Academic Year                                             2785
# Branch/ Specialisation                                    2783
# Other Branch                                              4659
# What is your current academic year?                       5172
# Company Name/ College Name                                5065
# Would you like to know more about us and our programs?       0
# ...

# %%
df2 = df.copy()

# %%
df2.head()
# Out:
#       ID First Name              Email Gender City                 Created  \
# 0  68112     ANIKET     aniket@xyz.com    NaN  NaN  04/27/2022 01:41:38 pm
# 1  68110  Dhanshree  dhanshree@xyz.com    NaN  NaN  04/22/2022 04:08:38 pm
# 2  68108     Dhiraj     dhiraj@xyz.com    NaN  NaN  04/16/2022 10:31:59 pm
# 3  68106      Pooja      pooja@xyz.com    NaN  NaN  04/13/2022 10:05:15 pm
# 4  68090     Aayush     aayush@xyz.com    NaN  NaN  03/26/2022 07:02:48 pm
#
#   Position         New College Name Colleges  Academic Year  \
# 0      NaN                      NaN      NaN            NaN
# 1      NaN  Lords Universal College      NaN            NaN
# 2      NaN                      NaN      NaN            NaN
# 3      NaN                      NaN      NaN            NaN
# 4      NaN        B.k Birla college      NaN            NaN
#
#   Branch/ Specialisation Other Branch What is your current academic year?  \
# 0                    NaN          NaN                                 NaN
# ...

# %%
df2.to_excel("year_of_placement_prediction.xlsx")
