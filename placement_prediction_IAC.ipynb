# %%
pip install --upgrade pyforest
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyforest: filename=pyforest-1.1.0-py2.py3-none-any.whl size=14605 sha256=822a09c2a3f055f1ac8bec213efe74b6058f5e810c1997afb329626581cc74cb
#   Stored in directory: /root/.cache/pip/wheels/9e/7d/2c/5d2f5e62de376c386fd3bf5a8e5bd119ace6a9f48f49df6017
# Successfully built pyforest
# ...

# %%
from pyforest import *

# %%
lazy_imports()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_excel("/content/01 Train Data.xlsx")

# %%
df.head()
# Out:
#   First Name           Email ID  Quantity  Price Tier             Ticket Type  \
# 0     ANIKET     aniket@xyz.com         1         NaN  Art of Resume Building
# 1  Dhanshree  dhanshree@xyz.com         1         NaN  Art of Resume Building
# 2     Dhiraj     dhiraj@xyz.com         1         NaN  Art of Resume Building
# 3      Pooja      pooja@xyz.com         1         NaN  Art of Resume Building
# 4     Aayush     aayush@xyz.com         1         NaN  Art of Resume Building
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.213855e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.213859e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.213862e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.213988e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.214567e+09    NaN  Free Order      USD           0  ...        Attending
#
# ...

# %%
df.shape
# Out:
# (4894, 23)

# %%
df.drop(df.columns[[0,1,2,3,4,5,6,7,9,11]],axis =1,inplace = True)

# %%
df.head()
# Out:
#   Currency  Fees Paid  Eventbrite Payment Processing Attendee Status  \
# 0      USD        0.0                              0       Attending
# 1      USD        0.0                              0       Attending
# 2      USD        0.0                              0       Attending
# 3      USD        0.0                              0       Attending
# 4      USD        0.0                              0       Attending
#
#                                         College Name  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Don Bosco College of Engineering Fatorda Goa
# 3           Pillai College of Engineering New Panvel
# 4                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# ...

# %%
df.drop(df.columns[[0,1]],axis =1,inplace = True)

# %%
df.dropna(subset = ['Placement Status'],axis =0,inplace =True)

# %%
df.value_counts("Placement Status")
# Out:
# Placement Status
# Not placed    732
# Placed        366
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Eventbrite Payment Processing                                         0
# Attendee Status                                                       0
# College Name                                                         14
# How did you come to know about this event?                            4
# Specify in "Others" (how did you come to know about this event)    1036
# Designation                                                           0
# Year of Graduation                                                 1098
# CGPA                                                                  0
# Speaking Skills                                                       0
# ML Knowledge                                                          0
# Placement Status                                                      0
# dtype: int64

# %%
df.head()
# Out:
#    Eventbrite Payment Processing Attendee Status  \
# 0                              0       Attending
# 1                              0       Attending
# 2                              0       Attending
# 3                              0       Attending
# 4                              0       Attending
#
#                                         College Name  \
# 0  D Y PATIL INSTITUTE OF MCA AND MANAGEMENT AKUR...
# 1                   AP SHAH INSTITUTE OF TECHNOLOGY
# 2       Don Bosco College of Engineering Fatorda Goa
# 3           Pillai College of Engineering New Panvel
# 4                               St Xavier's College
#
#         How did you come to know about this event?  \
# 0                                            Email
# 1                                           Others
# 2                                            Email
# 3                                            Email
# 4  Instagram | LinkedIn | Cloud Counselage Website
#
# ...

# %%
df.drop(df.columns[[0,1,2,3,4,5,6]],axis = 1,inplace = True)

# %%
df.head()
# Out:
#    CGPA  Speaking Skills  ML Knowledge Placement Status
# 0   6.7                2             5           Placed
# 1   8.2                3             2       Not placed
# 2   6.5                4             3       Not placed
# 3   8.7                2             5       Not placed
# 4   9.1                3             5           Placed

# %%
sns.pairplot(df)

# %%
y = df["Placement Status"]
x = df.drop("Placement Status",axis =1)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt  = DecisionTreeClassifier(criterion = 'gini',random_state =1)

# %%
dt.fit(x,y)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_pred =dt.predict(x)

# %%
dt.score(x,y)
# Out:
# 0.7249544626593807

# %%
df2 = pd.read_excel('/content/02 Test Data.xlsx')

# %%
x1 = df2[['CGPA','Speaking Skills','ML Knowledge']]

# %%
y_pred_of_test_data =dt.predict(x1)

# %%
df2['Placement Status'] = y_pred_of_test_data

# %%
df2["Placement Status"] = df2["Placement Status"].map({'Placed':1,'Not placed':0})

# %%
df2.head()
# Out:
#    First Name            Email ID  Quantity  Price Tier      Ticket Type  \
# 0      Sahil        sahil@xyz.com         1         NaN  Hello ML and DL
# 1     Amrita       amrita@xyz.com         1         NaN  Hello ML and DL
# 2       Mamta       mamta@xyz.com         1         NaN  Hello ML and DL
# 3  Bhagyashri  bhagyashri@xyz.com         1         NaN  Hello ML and DL
# 4   Divyanshu   divyanshu@xyz.com         1         NaN  Hello ML and DL
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.293940e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.293946e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.293956e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                      College Name  \
# ...

# %%
df['Placement Status'].value_counts()
# Out:
# Not placed    732
# Placed        366
# Name: Placement Status, dtype: int64

# %%
df2.to_excel('placement.xlsx')
